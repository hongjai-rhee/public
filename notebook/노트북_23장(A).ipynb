# %% [markdown]
# # **클래스를 사용한 달착륙선 PPO 실습**

# %% [markdown]
# ### 라이브러리 설치

# %%
# !pip install gymnasium[box2d]
import gymnasium as gym
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_probability as tfp
# Out:
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.6)
# Collecting box2d==2.3.10 (from gymnasium[box2d])
#   Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (573 bytes)
# Collecting pygame-ce>=2.1.3 (from gymnasium[box2d])
#   Downloading pygame_ce-2.5.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 98.8 MB/s eta 0:00:00
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 102.5 MB/s eta 0:00:00
# Downloading pygame_ce-2.5.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 96.5 MB/s eta 0:00:00
# Installing collected packages: swig, box2d, pygame-ce
# Successfully installed box2d-2.3.10 pygame-ce-2.5.7 swig-4.4.1

# %% [markdown]
# ---

# %% [markdown]
# ### 클래스 파일 업로드

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !wget https://raw.githubusercontent.com/hongjai-rhee/public/master/mini_PPO.py  # 클래스가 정의된 파일 지정
from mini_PPO import *   # 미리 만들어진 5개 PPO 클래스 임포트
# Out:
# --2026-08-02 05:15:20--  https://raw.githubusercontent.com/hongjai-rhee/public/master/mini_PPO.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12625 (12K) [text/plain]
# Saving to: ‘mini_PPO.py’
#
# mini_PPO.py         100%[===================>]  12.33K  --.-KB/s    in 0s
#
# 2026-08-02 05:15:20 (134 MB/s) - ‘mini_PPO.py’ saved [12625/12625]

# %% [markdown]
# ---
#
#
# ### **환경/모델 설정과 메인 학습 루프**

# %% [markdown]
# 로우레벨 코드는 SB3보다 시간이 오래 걸려, 작동 원리만 확인하기 위해
# * 총 학습 횟수인 TOTAL_STEPS를 10,000으로 지정하였습니다.
# * 완전한 학습을 위해서는 2백만번 이상의 학습이 필요할 수 있습니다.

# %%
# 환경 설정
env = gym.make('LunarLanderContinuous-v3')
state_dim  = env.observation_space.shape[0]   # 상태 수: 8
action_dim = env.action_space.shape[0]        # 행동 수: 2

# ── 모델 설정
setup    = ModelSetup(state_dim, action_dim,actor_lr=3e-4, critic_lr=3e-4) # 액터/크리틱 모델 설정

# ── 단계별 연산 방법 지정
take_act = TakeAction(setup)                                               # 행동 선택
rollout  = RolloutCollector(env, take_act, rollout_steps=1000)              # 경험 데이터 수집
eval_adv = EvaluateAdvantage(setup, gamma=0.99, lam=0.95)                  # 어드밴티지 계산(GAE 방법 적용)
update   = UpdateModel(setup, take_act, clip_eps=0.2, epochs=10, batch_size=256,
                       vf_coef=0.5,ent_coef = 0.05)                        # 모델 파라미터 업데이트

# ── 학습 루프 ──────────────────────────────────────────
TOTAL_STEPS = 10000   # 학습 횟수 지정(충분히 크게)

while rollout.step < TOTAL_STEPS:
    experience = rollout.collect()          # [1] 경험 데이터 수집
    exp_with_adv = eval_adv(experience)     # [2] 어드밴티지 계산
    losses = update(exp_with_adv)           # [3] 손실 계산 --> 업데이트

env.close()
# Out:
#   [Episode    1] Reward:  -469.06  Total_Steps:     125
#   [Episode    2] Reward:  -562.98  Total_Steps:     226
#   [Episode    3] Reward:   -63.15  Total_Steps:     313
#   [Episode    4] Reward:  -452.42  Total_Steps:     416
#   [Episode    5] Reward:  -381.60  Total_Steps:     514
#   [Episode    6] Reward:  -684.75  Total_Steps:     636
#   [Episode    7] Reward:  -517.86  Total_Steps:     727
#   [Episode    8] Reward:   -70.77  Total_Steps:     816
#   [Episode    9] Reward:  -350.71  Total_Steps:     918
#   [Episode   10] Reward:  -369.88  Total_Steps:    1049
#   [Episode   11] Reward:  -585.28  Total_Steps:    1207
#   [Episode   12] Reward:  -520.19  Total_Steps:    1310
#   [Episode   13] Reward:  -314.30  Total_Steps:    1413
#   [Episode   14] Reward:  -446.35  Total_Steps:    1509
#   [Episode   15] Reward:  -633.71  Total_Steps:    1676
#   [Episode   16] Reward:  -442.52  Total_Steps:    1770
#   [Episode   17] Reward:  -486.17  Total_Steps:    1915
#   [Episode   18] Reward:  -451.78  Total_Steps:    2076
#   [Episode   19] Reward:  -303.20  Total_Steps:    2165
#   [Episode   20] Reward:  -210.08  Total_Steps:    2283
#   [Episode   21] Reward:  -357.18  Total_Steps:    2402
#   [Episode   22] Reward:  -203.10  Total_Steps:    2535
#   [Episode   23] Reward:  -228.09  Total_Steps:    2650
#   [Episode   24] Reward:   -51.18  Total_Steps:    2780
#   [Episode   25] Reward:  -296.48  Total_Steps:    2877
#   [Episode   26] Reward:   -18.40  Total_Steps:    2999
#   [Episode   27] Reward:   -23.47  Total_Steps:    3158
#   [Episode   28] Reward:  -455.13  Total_Steps:    3293
#   [Episode   29] Reward:  -339.48  Total_Steps:    3434
#   [Episode   30] Reward:  -217.96  Total_Steps:    3546
#   [Episode   31] Reward:  -479.17  Total_Steps:    3720
#   [Episode   32] Reward:  -262.31  Total_Steps:    3805
#   [Episode   33] Reward:  -296.03  Total_Steps:    3894
#   [Episode   34] Reward:   -86.17  Total_Steps:    3995
#   [Episode   35] Reward:  -267.68  Total_Steps:    4146
#   [Episode   36] Reward:  -204.30  Total_Steps:    4280
#   [Episode   37] Reward:  -111.77  Total_Steps:    4492
#   [Episode   38] Reward:  -150.62  Total_Steps:    4613
#   [Episode   39] Reward:  -338.82  Total_Steps:    4724
#   [Episode   40] Reward:  -116.46  Total_Steps:    4873
#   [Episode   41] Reward:  -111.23  Total_Steps:    5047
#   [Episode   42] Reward:  -108.75  Total_Steps:    5146
#   [Episode   43] Reward:   -28.34  Total_Steps:    5254
#   [Episode   44] Reward:  -175.13  Total_Steps:    5385
#   [Episode   45] Reward:  -108.61  Total_Steps:    5501
#   [Episode   46] Reward:   -39.09  Total_Steps:    5604
#   [Episode   47] Reward:   -51.73  Total_Steps:    5695
#   [Episode   48] Reward:  -346.18  Total_Steps:    5813
#   [Episode   49] Reward:  -155.90  Total_Steps:    5928
#   [Episode   50] Reward:  -180.29  Total_Steps:    6017
#   [Episode   51] Reward:  -281.83  Total_Steps:    6197
#   [Episode   52] Reward:  -170.23  Total_Steps:    6356
#   [Episode   53] Reward:  -156.13  Total_Steps:    6456
#   [Episode   54] Reward:   -85.68  Total_Steps:    6592
#   [Episode   55] Reward:  -402.05  Total_Steps:    6747
#   [Episode   56] Reward:    19.84  Total_Steps:    6850
#   [Episode   57] Reward:   -67.28  Total_Steps:    6913
#   [Episode   58] Reward:  -503.64  Total_Steps:    7109
#   [Episode   59] Reward:  -105.41  Total_Steps:    7180
#   [Episode   60] Reward:  -302.13  Total_Steps:    7322
#   [Episode   61] Reward:  -180.30  Total_Steps:    7421
#   [Episode   62] Reward:  -378.56  Total_Steps:    7615
#   [Episode   63] Reward:  -133.32  Total_Steps:    7745
#   [Episode   64] Reward:   -31.04  Total_Steps:    7842
#   [Episode   65] Reward:  -380.96  Total_Steps:    7968
#   [Episode   66] Reward:  -235.74  Total_Steps:    8054
#   [Episode   67] Reward:  -311.47  Total_Steps:    8225
#   [Episode   68] Reward:  -145.31  Total_Steps:    8366
#   [Episode   69] Reward:  -191.69  Total_Steps:    8492
#   [Episode   70] Reward:  -343.75  Total_Steps:    8590
#   [Episode   71] Reward:  -107.20  Total_Steps:    8661
#   [Episode   72] Reward:  -174.73  Total_Steps:    8753
#   [Episode   73] Reward:   -54.36  Total_Steps:    8901
#   [Episode   74] Reward:   -37.02  Total_Steps:    9046
#   [Episode   75] Reward:  -453.39  Total_Steps:    9141
#   [Episode   76] Reward:  -546.89  Total_Steps:    9230
#   [Episode   77] Reward:  -487.77  Total_Steps:    9325
#   [Episode   78] Reward:  -128.60  Total_Steps:    9400
#   [Episode   79] Reward:  -354.72  Total_Steps:    9488
#   [Episode   80] Reward:  -112.48  Total_Steps:    9601
#   [Episode   81] Reward:  -356.81  Total_Steps:    9683
#   [Episode   82] Reward:  -385.05  Total_Steps:    9799
#   [Episode   83] Reward:  -260.22  Total_Steps:    9885

# %% [markdown]
#  EvaluateAdvantage 클래스에서는 **GAE**(Generalized Advantage Estimation) 기법을 사용했는데,
#  * 이는 PPO 학습의 안전성을 더욱 강화하기 위해 책에서 설명한 어드밴티지 계산을 Exponential Moving Average 형태로 일부 변형한 것입니다.
#  * 간단한 문제에서는 원래의 어드밴티지 계산을 사용해도 좋습니다.

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/QwJcF08hfs8?si=WO-buGL6CzIBOTCS" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
