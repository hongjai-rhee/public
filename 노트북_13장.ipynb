# %% [markdown]
# # **13장. 문장 생성 모델**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 이 영상의 처음 4분만 시청해봅시다.
# https://www.youtube.com/watch?v=LPZh9BOjkQs
#
# 문장 생성 모델은 대규모 언어모델(LLM)의 구조와 동일합니다.

# %%
# !pip install koreanize_matplotlib
import koreanize_matplotlib
import numpy as np; import matplotlib.pyplot as plt
import tensorflow as tf
import random; import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Embedding, Flatten, SimpleRNN, LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping
# Out:
# Collecting koreanize_matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from koreanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 33.1 MB/s eta 0:00:00
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %% [markdown]
# [실습 13-01]

# %%
# 말뭉치 파일 지정
file="AI소설.txt"

# 텍스트 파일 불러오기
with open(file, encoding="cp949") as f:
  text=f.read()

# 데이터 전처리
text=text.replace("\n", " ")
text=re.sub(r"([?.!,])", r" \1 ", text)
text
# Out:
# '낡은 라디오의 볼륨 다이얼을 돌릴 때마다 치직거리는 잡음 사이로 먼지 쌓인 주파수들이 비명을 질렀다 .  열일곱 살의 여름은 유난히 길었고 ,  실내 체육관의 코트 바닥처럼 후끈거리는 열기로 가득 차 있었다 .  민우는 외할아버지가 남긴 유품인 구식 라디오를 분해했다 조립하기를 반복하며 그 지루한 시간을 견디고 있었다 .  송신기가 고장 난 라디오는 소리 없이 침묵하고 있었고 ,  소년도 침묵하는 법을 익혀가는 중이었다 .  그날도 옥탑방의 창문 너머로 붉은 노을이 번져나가던 저녁이었다 .  민우가 조심스럽게 다이얼을 맞추던 순간 ,  기적처럼 잡음이 걷히고 맑은 목소리가 흘러나왔다 .  "안녕 ,  거기 누구 있나요 ?  제 목소리가 들리나요 ? " 그것은 마치 아주 먼 곳에서 날아온 전파가 옥탑방에만 내려앉은 것 같은 ,  믿기지 않는 순간이었다 .  목소리의 주인은 자신을 서연이라고 소개했고 ,  민우는 홀린 듯 마이크를 잡고 대답했다 .  "네 ,  들려요 .  아주 잘 들려요 . " 두 사람의 비밀스러운 주파수는 매일 밤 같은 시각에 맞춰졌다 .  서연은 창밖으로 보이는 노을의 색깔을 물었고 ,  민우는 눈앞에 펼쳐진 풍경을 시처럼 묘사해주었다 .  서연은 민우에게 한 번도 가보지 못한 바다의 파도 소리를 들려주었고 ,  민우는 그 소리를 들으며 침대 위에서 파도를 타는 상상을 했다 .  그들은 서로의 얼굴도 ,  사는 곳도 몰랐지만 ,  주파수라는 투명한 실로 연결된 채 서로의 깊은 속마음을 나누었다 .  어느덧 여름이 끝나가고 소나기가 퍼붓던 밤 ,  서연의 목소리가 유난히 가늘게 떨렸다 .  "민우야 ,  만약 이 신호가 끊겨도 우리 다시 만날 수 있을까 ? " 민우는 가슴 한구석이 아릿해지는 것을 느끼며 꼭 다시 만나자고 ,  내가 너를 찾아내겠다고 약속했다 .  하지만 그 약속을 비웃듯 거대한 천둥소리와 함께 전구의 불빛이 깜빡거렸다 .  치직 ,  거리는 귀를 찢는 듯한 소음이 다시 시작되었고 ,  소녀는 거짓말처럼 사라졌다 .  해안가 마을의 낡은 등대 아래에는 매일 아침 정체 모를 유리병들이 파도에 밀려와 모래사장에 박혔다 .  열여덟 살의 겨울은 유난히 추웠고 ,  항구의 방파제 너머로 몰아치는 찬바람은 날카로운 얼음 조각처럼 살결을 파고들었다 .  수호는 바닷바람이 실어온 유리병을 수집하고 닦아내기를 반복하며 그 지루한 계절을 견디고 있었다 .  입구가 깨진 병은 아무런 소식도 담지 못한 채 침묵하고 있었고 ,  청년 역시 침묵하는 법을 익혀가는 중이었다 .  어느 날도 해변의 바위 너머로 푸른 새벽빛이 번져나가던 아침이었다 .  수호가 조심스럽게 모래를 털어내던 순간 ,  기적처럼 유리병 속에 담긴 낡은 종이 한 장이 보였다 .  "거기 누군가 있나요 ?  제 편지가 보이나요 ? " 그것은 마치 아주 먼 섬에서 날아온 우편물이 발밑에만 내려앉은 것 같은 ,  믿기지 않는 순간이었다 .  편지의 주인은 자신을 다인이라고 소개했고 ,  소년은 홀린 듯 펜을 잡고 답장을 적었다 .  "네 ,  보여요 .  아주 잘 보여요 . " 두 사람의 비밀스러운 우편물은 매일 새벽 밀물 시각에 맞춰졌다 .  다인은 수평선 너머 보이는 파도의 색깔을 물었고 ,  수호는 눈앞에 펼쳐진 바다를 시처럼 묘사해주었다 .  다인은 수호에게 가보지 못한 숲의 바람 소리를 들려주었고 ,  수호는 그 글을 읽으며 해안가 침대 위에서 숲길을 걷는 상상을 했다 .  그들은 서로의 얼굴도 ,  사는 곳도 몰랐지만 ,  편지라는 투명한 실로 연결된 채 서로의 깊은 속마음을 나누었다 .  어느덧 겨울이 끝나가고 눈보라가 퍼붓던 밤 ,  다인의 글씨가 유난히 가늘게 떨렸다 .  "수호야 ,  만약 이 유리병이 끊겨도 우리 다시 만날 수 있을까 ? " 수호는 가슴 한구석이 아릿해지는 것을 느끼며 꼭 다시 만나자고 ,  내가 너를 찾아내겠다고 약속했다 .  하지만 그 약속을 비웃듯 거대한 파도 소리와 함께 등대의 불빛이 깜빡거렸다 .  휘익 ,  거리는 귀를 찢는 듯한 바람 소리가 다시 시작되었고 ,  소녀의 편지는 거짓말처럼 사라졌다 .  시계탑 아래의 작은 수리점 안에는 매일 오후 정체 모를 부품들이 상자 가득 담겨 문 앞에 놓였다 .  열아홉 살의 봄은 유난히 서늘했고 ,  광장 너머로 불어오는 흙먼지는 거친 모래알처럼 폐부 깊숙이 파고들었다 .  진우는 시계 태엽을 감고 톱니바퀴를 닦아내기를 반복하며 그 지루한 나날을 견디고 있었다 .  초침이 부러진 시계는 아무런 시간도 가리키지 못한 채 침묵하고 있었고 ,  진우 역시 침묵하는 법을 익혀가는 중이었다 .  어느 날도 시계탑 너머로 노란 햇살이 번져나가던 오후였다 .  진우가 조심스럽게 태엽을 조이던 순간 ,  기적처럼 멈춰있던 모래시계 속에서 미세한 진동이 느껴졌다 .  "거기 누군가 있나요 ?  제 소리가 들리나요 ? " 그것은 마치 아주 먼 과거에서 날아온 신호가 수리점에만 내려앉은 것 같은 ,  믿기지 않는 순간이었다 .  신호의 주인은 자신을 하윤이라고 소개했고 ,  진우는 홀린 듯 펜을 잡고 숫자를 적었다 .  "네 ,  들려요 .  아주 잘 들려요 . " 두 사람의 비밀스러운 신호는 매일 정오 시계가 울리는 시각에 맞춰졌다 .  하윤은 창밖으로 보이는 꽃잎의 색깔을 물었고 ,  진우는 눈앞에 펼쳐진 광장을 시처럼 묘사해주었다 .  하윤은 진우에게 한 번도 가보지 못한 산의 숲소리를 들려주었고 ,  소년은 그 소리를 들으며 작업대 옆 침대 위에서 산길을 걷는 상상을 했다 .  그들은 서로의 얼굴도 ,  사는 곳도 몰랐지만 ,  소음이라는 투명한 실로 연결된 채 서로의 깊은 속마음을 나누었다 .  어느덧 봄이 끝나가고 황사가 퍼붓던 밤 ,  하윤의 신호가 유난히 가늘게 떨렸다 .  "진우야 ,  만약 이 시계가 멈춰도 우리 다시 만날 수 있을까 ? " 진우는 가슴 한구석이 아릿해지는 것을 느끼며 꼭 다시 만나자고 ,  내가 너를 찾아내겠다고 약속했다 .  하지만 약속을 비웃듯 거대한 종소리와 함께 가게의 불빛이 깜빡거렸다 .  끼익 ,  거리는 귀를 찢는 듯한 소음이 다시 시작되었고 ,  소녀가 보낸 신호는 거짓말처럼 사라졌다 .   '

# %% [markdown]
# [실습 13-02]

# %%
tokenizer = Tokenizer(filters='') # 토크나이저 정의
tokenizer.fit_on_texts([text])  # 토크나이저 최적화

text_encoded = tokenizer.texts_to_sequences([text])[0] # 라벨인코딩

print("라벨 인코딩된 토큰")
print(text_encoded)
# Out:
# 라벨 인코딩된 토큰
# [22, 158, 159, 124, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 1, 170, 23, 171, 7, 172, 2, 173, 174, 175, 176, 177, 178, 125, 179, 15, 1, 10, 180, 181, 182, 183, 184, 185, 186, 24, 6, 25, 187, 26, 15, 1, 188, 189, 190, 191, 192, 193, 27, 28, 2, 194, 29, 30, 31, 32, 1, 195, 196, 197, 11, 198, 199, 33, 200, 1, 201, 34, 124, 202, 35, 2, 36, 203, 204, 205, 37, 206, 1, 207, 2, 208, 209, 38, 3, 39, 37, 126, 3, 4, 40, 41, 8, 42, 210, 43, 211, 212, 44, 45, 16, 2, 46, 47, 48, 1, 213, 49, 50, 214, 51, 2, 10, 52, 53, 215, 54, 216, 1, 55, 2, 17, 1, 8, 56, 17, 1, 4, 57, 58, 59, 217, 12, 18, 16, 60, 61, 1, 127, 128, 62, 218, 63, 64, 2, 10, 65, 66, 219, 67, 68, 1, 127, 220, 69, 129, 70, 13, 221, 130, 19, 71, 2, 10, 6, 19, 131, 72, 73, 222, 223, 74, 75, 1, 76, 9, 77, 2, 78, 79, 80, 2, 224, 81, 82, 83, 14, 9, 84, 85, 86, 1, 87, 225, 88, 226, 89, 18, 2, 227, 37, 7, 90, 91, 1, 228, 2, 92, 93, 94, 132, 95, 5, 96, 97, 98, 3, 4, 10, 99, 100, 101, 102, 103, 104, 5, 105, 2, 106, 107, 108, 109, 1, 110, 6, 111, 112, 113, 229, 114, 230, 115, 116, 1, 231, 2, 117, 118, 119, 120, 133, 5, 121, 2, 232, 122, 123, 1, 134, 233, 22, 234, 235, 12, 236, 135, 136, 237, 238, 239, 240, 241, 1, 242, 23, 243, 7, 244, 2, 245, 246, 11, 247, 248, 249, 250, 251, 252, 137, 1, 20, 253, 254, 255, 256, 138, 24, 6, 25, 257, 26, 15, 1, 258, 259, 260, 139, 261, 262, 13, 14, 27, 28, 2, 263, 140, 29, 30, 31, 32, 1, 141, 142, 264, 265, 11, 266, 267, 33, 268, 1, 269, 34, 270, 271, 35, 2, 36, 272, 273, 274, 22, 275, 69, 276, 277, 1, 143, 144, 38, 3, 39, 278, 279, 3, 4, 40, 41, 8, 42, 280, 43, 281, 282, 44, 45, 16, 2, 46, 47, 48, 1, 283, 49, 50, 284, 51, 2, 145, 52, 53, 146, 54, 285, 147, 1, 55, 2, 148, 1, 8, 56, 148, 1, 4, 57, 58, 59, 286, 12, 287, 288, 60, 61, 1, 149, 289, 290, 62, 291, 63, 64, 2, 20, 65, 66, 292, 67, 68, 1, 149, 293, 70, 13, 294, 150, 19, 71, 2, 20, 6, 295, 296, 134, 72, 73, 297, 151, 74, 75, 1, 76, 9, 77, 2, 78, 79, 80, 2, 298, 81, 82, 83, 14, 9, 84, 85, 86, 1, 87, 299, 88, 300, 89, 18, 2, 301, 302, 7, 90, 91, 1, 303, 2, 92, 93, 304, 132, 95, 5, 96, 97, 98, 3, 4, 20, 99, 100, 101, 102, 103, 104, 5, 105, 2, 106, 107, 108, 109, 1, 110, 6, 111, 112, 113, 130, 305, 114, 306, 115, 116, 1, 307, 2, 117, 118, 119, 120, 150, 152, 5, 121, 2, 308, 309, 122, 123, 1, 153, 310, 311, 312, 313, 12, 314, 135, 136, 315, 316, 125, 317, 318, 319, 320, 1, 321, 23, 322, 7, 323, 2, 324, 11, 325, 326, 327, 328, 329, 330, 137, 1, 21, 331, 154, 332, 333, 138, 24, 6, 25, 334, 26, 15, 1, 335, 336, 337, 139, 338, 339, 13, 14, 27, 28, 2, 340, 140, 29, 30, 31, 32, 1, 141, 142, 153, 11, 341, 342, 33, 343, 1, 344, 34, 154, 345, 35, 2, 36, 346, 347, 348, 349, 350, 351, 1, 143, 144, 38, 3, 39, 152, 126, 3, 4, 40, 41, 8, 42, 352, 43, 94, 353, 44, 45, 16, 2, 46, 47, 48, 1, 354, 49, 50, 355, 51, 2, 21, 52, 53, 146, 54, 356, 147, 1, 55, 2, 17, 1, 8, 56, 17, 1, 4, 57, 58, 59, 155, 12, 357, 156, 358, 60, 61, 1, 157, 128, 62, 359, 63, 64, 2, 21, 65, 66, 360, 67, 68, 1, 157, 361, 69, 129, 70, 13, 362, 363, 71, 2, 145, 6, 19, 131, 364, 365, 72, 73, 366, 151, 74, 75, 1, 76, 9, 77, 2, 78, 79, 80, 2, 367, 81, 82, 83, 14, 9, 84, 85, 86, 1, 87, 368, 88, 369, 89, 18, 2, 370, 94, 7, 90, 91, 1, 371, 2, 92, 93, 156, 372, 95, 5, 96, 97, 98, 3, 4, 21, 99, 100, 101, 102, 103, 104, 5, 105, 2, 106, 107, 108, 109, 1, 110, 111, 112, 113, 373, 114, 374, 115, 116, 1, 375, 2, 117, 118, 119, 120, 133, 5, 121, 2, 376, 377, 155, 122, 123, 1]

# %% [markdown]
# [실습 13-03]

# %%
print("인코딩 딕셔너리")
print(tokenizer.word_index); print()
print("토큰 '유난히'의 인덱스:", tokenizer.word_index['유난히']); print()
index_word={v: k for k, v in tokenizer.word_index.items()}
print("디코딩 딕셔너리")
print(index_word); print()
print("7번 인덱스의 토큰:", index_word.get(7)); print()

vocab_size = len(tokenizer.word_index) + 1
print(f"고유 토큰의 수: {vocab_size}")
# Out:
# 인코딩 딕셔너리
# {'.': 1, ',': 2, '?': 3, '"': 4, '다시': 5, '그': 6, '유난히': 7, '아주': 8, '서로의': 9, '민우는': 10, '너머로': 11, '매일': 12, '못한': 13, '채': 14, '있었다': 15, '같은': 16, '들려요': 17, '밤': 18, '소리를': 19, '수호는': 20, '진우는': 21, '낡은': 22, '살의': 23, '반복하며': 24, '지루한': 25, '견디고': 26, '침묵하고': 27, '있었고': 28, '침묵하는': 29, '법을': 30, '익혀가는': 31, '중이었다': 32, '번져나가던': 33, '조심스럽게': 34, '순간': 35, '기적처럼': 36, '목소리가': 37, '있나요': 38, '제': 39, '그것은': 40, '마치': 41, '먼': 42, '날아온': 43, '내려앉은': 44, '것': 45, '믿기지': 46, '않는': 47, '순간이었다': 48, '주인은': 49, '자신을': 50, '소개했고': 51, '홀린': 52, '듯': 53, '잡고': 54, '"네': 55, '잘': 56, '두': 57, '사람의': 58, '비밀스러운': 59, '시각에': 60, '맞춰졌다': 61, '보이는': 62, '색깔을': 63, '물었고': 64, '눈앞에': 65, '펼쳐진': 66, '시처럼': 67, '묘사해주었다': 68, '한': 69, '가보지': 70, '들려주었고': 71, '침대': 72, '위에서': 73, '상상을': 74, '했다': 75, '그들은': 76, '얼굴도': 77, '사는': 78, '곳도': 79, '몰랐지만': 80, '투명한': 81, '실로': 82, '연결된': 83, '깊은': 84, '속마음을': 85, '나누었다': 86, '어느덧': 87, '끝나가고': 88, '퍼붓던': 89, '가늘게': 90, '떨렸다': 91, '만약': 92, '이': 93, '신호가': 94, '우리': 95, '만날': 96, '수': 97, '있을까': 98, '가슴': 99, '한구석이': 100, '아릿해지는': 101, '것을': 102, '느끼며': 103, '꼭': 104, '만나자고': 105, '내가': 106, '너를': 107, '찾아내겠다고': 108, '약속했다': 109, '하지만': 110, '약속을': 111, '비웃듯': 112, '거대한': 113, '함께': 114, '불빛이': 115, '깜빡거렸다': 116, '거리는': 117, '귀를': 118, '찢는': 119, '듯한': 120, '시작되었고': 121, '거짓말처럼': 122, '사라졌다': 123, '다이얼을': 124, '가득': 125, '들리나요': 126, '서연은': 127, '창밖으로': 128, '번도': 129, '파도': 130, '들으며': 131, '끊겨도': 132, '소음이': 133, '해안가': 134, '정체': 135, '모를': 136, '파고들었다': 137, '닦아내기를': 138, '아무런': 139, '역시': 140, '어느': 141, '날도': 142, '"거기': 143, '누군가': 144, '소년은': 145, '펜을': 146, '적었다': 147, '보여요': 148, '다인은': 149, '바람': 150, '걷는': 151, '소리가': 152, '시계탑': 153, '태엽을': 154, '신호는': 155, '시계가': 156, '하윤은': 157, '라디오의': 158, '볼륨': 159, '돌릴': 160, '때마다': 161, '치직거리는': 162, '잡음': 163, '사이로': 164, '먼지': 165, '쌓인': 166, '주파수들이': 167, '비명을': 168, '질렀다': 169, '열일곱': 170, '여름은': 171, '길었고': 172, '실내': 173, '체육관의': 174, '코트': 175, '바닥처럼': 176, '후끈거리는': 177, '열기로': 178, '차': 179, '외할아버지가': 180, '남긴': 181, '유품인': 182, '구식': 183, '라디오를': 184, '분해했다': 185, '조립하기를': 186, '시간을': 187, '송신기가': 188, '고장': 189, '난': 190, '라디오는': 191, '소리': 192, '없이': 193, '소년도': 194, '그날도': 195, '옥탑방의': 196, '창문': 197, '붉은': 198, '노을이': 199, '저녁이었다': 200, '민우가': 201, '맞추던': 202, '잡음이': 203, '걷히고': 204, '맑은': 205, '흘러나왔다': 206, '"안녕': 207, '거기': 208, '누구': 209, '곳에서': 210, '전파가': 211, '옥탑방에만': 212, '목소리의': 213, '서연이라고': 214, '마이크를': 215, '대답했다': 216, '주파수는': 217, '노을의': 218, '풍경을': 219, '민우에게': 220, '바다의': 221, '파도를': 222, '타는': 223, '주파수라는': 224, '여름이': 225, '소나기가': 226, '서연의': 227, '"민우야': 228, '천둥소리와': 229, '전구의': 230, '치직': 231, '소녀는': 232, '마을의': 233, '등대': 234, '아래에는': 235, '아침': 236, '유리병들이': 237, '파도에': 238, '밀려와': 239, '모래사장에': 240, '박혔다': 241, '열여덟': 242, '겨울은': 243, '추웠고': 244, '항구의': 245, '방파제': 246, '몰아치는': 247, '찬바람은': 248, '날카로운': 249, '얼음': 250, '조각처럼': 251, '살결을': 252, '바닷바람이': 253, '실어온': 254, '유리병을': 255, '수집하고': 256, '계절을': 257, '입구가': 258, '깨진': 259, '병은': 260, '소식도': 261, '담지': 262, '청년': 263, '해변의': 264, '바위': 265, '푸른': 266, '새벽빛이': 267, '아침이었다': 268, '수호가': 269, '모래를': 270, '털어내던': 271, '유리병': 272, '속에': 273, '담긴': 274, '종이': 275, '장이': 276, '보였다': 277, '편지가': 278, '보이나요': 279, '섬에서': 280, '우편물이': 281, '발밑에만': 282, '편지의': 283, '다인이라고': 284, '답장을': 285, '우편물은': 286, '새벽': 287, '밀물': 288, '수평선': 289, '너머': 290, '파도의': 291, '바다를': 292, '수호에게': 293, '숲의': 294, '글을': 295, '읽으며': 296, '숲길을': 297, '편지라는': 298, '겨울이': 299, '눈보라가': 300, '다인의': 301, '글씨가': 302, '"수호야': 303, '유리병이': 304, '소리와': 305, '등대의': 306, '휘익': 307, '소녀의': 308, '편지는': 309, '아래의': 310, '작은': 311, '수리점': 312, '안에는': 313, '오후': 314, '부품들이': 315, '상자': 316, '담겨': 317, '문': 318, '앞에': 319, '놓였다': 320, '열아홉': 321, '봄은': 322, '서늘했고': 323, '광장': 324, '불어오는': 325, '흙먼지는': 326, '거친': 327, '모래알처럼': 328, '폐부': 329, '깊숙이': 330, '시계': 331, '감고': 332, '톱니바퀴를': 333, '나날을': 334, '초침이': 335, '부러진': 336, '시계는': 337, '시간도': 338, '가리키지': 339, '진우': 340, '노란': 341, '햇살이': 342, '오후였다': 343, ...
#
# 토큰 '유난히'의 인덱스: 7
#
# 디코딩 딕셔너리
# {1: '.', 2: ',', 3: '?', 4: '"', 5: '다시', 6: '그', 7: '유난히', 8: '아주', 9: '서로의', 10: '민우는', 11: '너머로', 12: '매일', 13: '못한', 14: '채', 15: '있었다', 16: '같은', 17: '들려요', 18: '밤', 19: '소리를', 20: '수호는', 21: '진우는', 22: '낡은', 23: '살의', 24: '반복하며', 25: '지루한', 26: '견디고', 27: '침묵하고', 28: '있었고', 29: '침묵하는', 30: '법을', 31: '익혀가는', 32: '중이었다', 33: '번져나가던', 34: '조심스럽게', 35: '순간', 36: '기적처럼', 37: '목소리가', 38: '있나요', 39: '제', 40: '그것은', 41: '마치', 42: '먼', 43: '날아온', 44: '내려앉은', 45: '것', 46: '믿기지', 47: '않는', 48: '순간이었다', 49: '주인은', 50: '자신을', 51: '소개했고', 52: '홀린', 53: '듯', 54: '잡고', 55: '"네', 56: '잘', 57: '두', 58: '사람의', 59: '비밀스러운', 60: '시각에', 61: '맞춰졌다', 62: '보이는', 63: '색깔을', 64: '물었고', 65: '눈앞에', 66: '펼쳐진', 67: '시처럼', 68: '묘사해주었다', 69: '한', 70: '가보지', 71: '들려주었고', 72: '침대', 73: '위에서', 74: '상상을', 75: '했다', 76: '그들은', 77: '얼굴도', 78: '사는', 79: '곳도', 80: '몰랐지만', 81: '투명한', 82: '실로', 83: '연결된', 84: '깊은', 85: '속마음을', 86: '나누었다', 87: '어느덧', 88: '끝나가고', 89: '퍼붓던', 90: '가늘게', 91: '떨렸다', 92: '만약', 93: '이', 94: '신호가', 95: '우리', 96: '만날', 97: '수', 98: '있을까', 99: '가슴', 100: '한구석이', 101: '아릿해지는', 102: '것을', 103: '느끼며', 104: '꼭', 105: '만나자고', 106: '내가', 107: '너를', 108: '찾아내겠다고', 109: '약속했다', 110: '하지만', 111: '약속을', 112: '비웃듯', 113: '거대한', 114: '함께', 115: '불빛이', 116: '깜빡거렸다', 117: '거리는', 118: '귀를', 119: '찢는', 120: '듯한', 121: '시작되었고', 122: '거짓말처럼', 123: '사라졌다', 124: '다이얼을', 125: '가득', 126: '들리나요', 127: '서연은', 128: '창밖으로', 129: '번도', 130: '파도', 131: '들으며', 132: '끊겨도', 133: '소음이', 134: '해안가', 135: '정체', 136: '모를', 137: '파고들었다', 138: '닦아내기를', 139: '아무런', 140: '역시', 141: '어느', 142: '날도', 143: '"거기', 144: '누군가', 145: '소년은', 146: '펜을', 147: '적었다', 148: '보여요', 149: '다인은', 150: '바람', 151: '걷는', 152: '소리가', 153: '시계탑', 154: '태엽을', 155: '신호는', 156: '시계가', 157: '하윤은', 158: '라디오의', 159: '볼륨', 160: '돌릴', 161: '때마다', 162: '치직거리는', 163: '잡음', 164: '사이로', 165: '먼지', 166: '쌓인', 167: '주파수들이', 168: '비명을', 169: '질렀다', 170: '열일곱', 171: '여름은', 172: '길었고', 173: '실내', 174: '체육관의', 175: '코트', 176: '바닥처럼', 177: '후끈거리는', 178: '열기로', 179: '차', 180: '외할아버지가', 181: '남긴', 182: '유품인', 183: '구식', 184: '라디오를', 185: '분해했다', 186: '조립하기를', 187: '시간을', 188: '송신기가', 189: '고장', 190: '난', 191: '라디오는', 192: '소리', 193: '없이', 194: '소년도', 195: '그날도', 196: '옥탑방의', 197: '창문', 198: '붉은', 199: '노을이', 200: '저녁이었다', 201: '민우가', 202: '맞추던', 203: '잡음이', 204: '걷히고', 205: '맑은', 206: '흘러나왔다', 207: '"안녕', 208: '거기', 209: '누구', 210: '곳에서', 211: '전파가', 212: '옥탑방에만', 213: '목소리의', 214: '서연이라고', 215: '마이크를', 216: '대답했다', 217: '주파수는', 218: '노을의', 219: '풍경을', 220: '민우에게', 221: '바다의', 222: '파도를', 223: '타는', 224: '주파수라는', 225: '여름이', 226: '소나기가', 227: '서연의', 228: '"민우야', 229: '천둥소리와', 230: '전구의', 231: '치직', 232: '소녀는', 233: '마을의', 234: '등대', 235: '아래에는', 236: '아침', 237: '유리병들이', 238: '파도에', 239: '밀려와', 240: '모래사장에', 241: '박혔다', 242: '열여덟', 243: '겨울은', 244: '추웠고', 245: '항구의', 246: '방파제', 247: '몰아치는', 248: '찬바람은', 249: '날카로운', 250: '얼음', 251: '조각처럼', 252: '살결을', 253: '바닷바람이', 254: '실어온', 255: '유리병을', 256: '수집하고', 257: '계절을', 258: '입구가', 259: '깨진', 260: '병은', 261: '소식도', 262: '담지', 263: '청년', 264: '해변의', 265: '바위', 266: '푸른', 267: '새벽빛이', 268: '아침이었다', 269: '수호가', 270: '모래를', 271: '털어내던', 272: '유리병', 273: '속에', 274: '담긴', 275: '종이', 276: '장이', 277: '보였다', 278: '편지가', 279: '보이나요', 280: '섬에서', 281: '우편물이', 282: '발밑에만', 283: '편지의', 284: '다인이라고', 285: '답장을', 286: '우편물은', 287: '새벽', 288: '밀물', 289: '수평선', 290: '너머', 291: '파도의', 292: '바다를', 293: '수호에게', 294: '숲의', 295: '글을', 296: '읽으며', 297: '숲길을', 298: '편지라는', 299: '겨울이', 300: '눈보라가', 301: '다인의', 302: '글씨가', 303: '"수호야', 304: '유리병이', 305: '소리와', 306: '등대의', 307: '휘익', 308: '소녀의', 309: '편지는', 310: '아래의', 311: '작은', 312: '수리점', 313: '안에는', 314: '오후', 315: '부품들이', 316: '상자', 317: '담겨', 318: '문', 319: '앞에', 320: '놓였다', 321: '열아홉', 322: '봄은', 323: '서늘했고', 324: '광장', 325: '불어오는', 326: '흙먼지는', 327: '거친', 328: '모래알처럼', 329: '폐부', 330: '깊숙이', 331: '시계', 332: '감고', 333: '톱니바퀴를', 334: '나날을', 335: '초침이', 336: '부러진', 337: '시계는', 338: '시간도', 339: '가리키지', 340: '진우', 341: '노란', 342: '햇살이', 343: '오후였다', ...
#
# 7번 인덱스의 토큰: 유난히
#
# 고유 토큰의 수: 378

# %% [markdown]
# [실습 13-04]

# %%
seq_length=10  # 시퀀스 길이

X, y = [], []
for i in range(len(text_encoded) - seq_length):
    X.append(text_encoded[i : i + seq_length])
    y.append(text_encoded[i + 1 : i + 1+ seq_length])

X = np.array(X); y = np.array(y)
print("피처 shape=", X.shape); print(X); print()
print("타깃 shape=", y.shape); print(y)
# Out:
# 피처 shape= (790, 10)
# [[ 22 158 159 ... 163 164 165]
#  [158 159 124 ... 164 165 166]
#  [159 124 160 ... 165 166 167]
#  ...
#  [118 119 120 ... 376 377 155]
#  [119 120 133 ... 377 155 122]
#  [120 133   5 ... 155 122 123]]
#
# 타깃 shape= (790, 10)
# [[158 159 124 ... 164 165 166]
#  [159 124 160 ... 165 166 167]
#  [124 160 161 ... 166 167 168]
#  ...
#  [119 120 133 ... 377 155 122]
#  [120 133   5 ... 155 122 123]
#  [133   5 121 ... 122 123   1]]

# %% [markdown]
# **큰 말뭉치라면 아래처럼 데이터를 분할하여 학습을 할 수 있습니다.**
#
# 이것이 LLM의 표준적인 방법입니다.

# %%
split=int(len(X)*0.8)  # 분할 시점 설정
print("분할 시점 =", split)
x_train=X[:split]; x_test=X[split:]
y_train=y[:split]; y_test=y[split:]
print("훈련용 입력 데이터 차원:", x_train.shape); print("훈련용 타깃 데이터 차원:", y_train.shape); print()
print("검증용 입력 데이터 차원:", x_test.shape); print("검증용 타깃 데이터 차원:", y_test.shape)
# Out:
# 분할 시점 = 632
# 훈련용 입력 데이터 차원: (632, 10)
# 훈련용 타깃 데이터 차원: (632, 10)
#
# 검증용 입력 데이터 차원: (158, 10)
# 검증용 타깃 데이터 차원: (158, 10)

# %% [markdown]
# **하지만 작은 말뭉치에서는 앞뒤 부분의 토큰 분포가 매우 달라서, 이러한 분할 검증 방법이 잘 작동하지 않습니다**.
#
# 따라서 이 실습에서는 **전체 데이터**를 사용하여 학습하되, 과대적합을 막기 위해 **에포크 수를 조절**하는 방법을 사용합니다.

# %% [markdown]
# ---
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [실습 13-05] & [실습 13-06]

# %%
# 랜덤 시드 고정
SEED = 42; np.random.seed(SEED); tf.random.set_seed(SEED); random.seed(SEED)

# 임베딩 차원
embedding_dim=32

# 모델 설정
model=Sequential([
    Input(shape=X[0].shape),
    Embedding(input_dim=vocab_size, output_dim=embedding_dim),

    GRU(64, return_sequences=True),

    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(vocab_size, activation='softmax') ])

# 컴파일
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="adam", metrics=['accuracy'])

# 학습 (전체 데이터 사용)
history=model.fit(X, y, epochs=20)  # 에포크 수 조절(최종 accuracy를 0.5~0.7 정도로 권장)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.0672 - loss: 5.9143
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0818 - loss: 5.7041
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0932 - loss: 5.4449
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1044 - loss: 5.1218
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1225 - loss: 4.7162
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1487 - loss: 4.2243
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2166 - loss: 3.6354
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3090 - loss: 3.0917
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4106 - loss: 2.5773
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4870 - loss: 2.1800
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5601 - loss: 1.8259
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6148 - loss: 1.5561
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6608 - loss: 1.3382
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6934 - loss: 1.1728
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7277 - loss: 1.0331
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7439 - loss: 0.9302
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7613 - loss: 0.8472
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7846 - loss: 0.7620
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7933 - loss: 0.7118
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8038 - loss: 0.6487

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 샘플링 기법의 문장 생성 함수

# %%
def generate(seed_text, length, temperature=1.0):
    generated_tokens = []

    for _ in range(length):
        # 1. 시드 텍스트 토큰화 및 시퀀스 길이 맞추기
        curr_tokens = tokenizer.texts_to_sequences([seed_text])[0]
        if len(curr_tokens) > seq_length:
            curr_tokens = curr_tokens[-seq_length:]
        pad_tokens = pad_sequences([curr_tokens], maxlen=seq_length, padding='pre')

        # 2. 모델에 입력하여 확률 예측
        probs_all = model.predict(pad_tokens, verbose=0)  # 모든 타임 스텝
        probs = probs_all[0, -1, :]                       # 마지막 타임 스텝의 확률만 추출

        # 3. 반복 패널티 적용 (최근 생성된 20개 토큰의 확률을 2배 축소)
        # 팁: 나눗셈 비율(1.5~2.0)을 직접 조절하여 페널티 강도를 조절할 수 있습니다.
        for token in set(generated_tokens[-20:]):
            probs[token] /= 2

        # 4. Temperature를 적용하여 확률 분포의 뾰족함을 조절
        p_temp = np.log(probs + 1e-10) / temperature
        next_probs = np.exp(p_temp)
        next_probs = next_probs / np.sum(next_probs)

        # 5. 샘플링 및 시드 텍스트 업데이트
        next_index = np.random.choice(len(next_probs), p=next_probs)
        generated_tokens.append(next_index)
        word = index_word.get(next_index)

        # 특수 토큰이나 존재하지 않는 단어를 만나면 종료
        if not word or word == '<pad>':
            break

        seed_text = seed_text + " " + word  # 시드 업데이트

    return seed_text

# %% [markdown]
# ### 생성 결과

# %% [markdown]
# [실습 13-07]

# %%
import textwrap
SEED= "낡은 라디오의 볼륨 다이얼을 돌릴 때마다"
output = generate(seed_text=SEED, length=200, temperature=0.7)
print(textwrap.fill(output, width=60))  # 출력 넓이 조절
# Out:
# 낡은 라디오의 볼륨 다이얼을 돌릴 때마다 치직거리는 잡음 사이로 먼지 쌓인 주파수들이 비명을 질렀다 .
# 열일곱 살의 봄은 유난히 길었고 , 광장 너머로 불어오는 흙먼지는 거친 모래알처럼 폐부 깊숙이 파고들었다 .
# 수호는 바닷바람이 실어온 유리병을 수집하고 닦아내기를 반복하며 그 지루한 시간을 견디고 있었다 . 하윤은
# 창밖으로 보이는 노을의 색깔을 물었고 , 소년은 홀린 듯 펜을 잡고 답장을 적었다 . "네 , 들려요 .
# 아주 잘 들려요 . " 두 사람의 비밀스러운 신호는 매일 오후 정체 모를 유리병들이 밀려와 모래사장에 박혔다
# . 진우가 조심스럽게 태엽을 조이던 순간 , 기적처럼 잡음이 걷히고 맑은 목소리가 흘러나왔다 . "안녕 ,
# 거기 누구 있나요 ? " 그것은 마치 아주 먼 곳에서 날아온 전파가 옥탑방에만 내려앉은 것 같은 , 믿기지
# 않는 순간이었다 . 편지의 주인은 자신을 다인이라고 소개했고 , 소년은 홀린 듯 마이크를 잡고 대답했다 .
# "네 , 들려요 . 아주 잘 들려요 . " 두 사람의 비밀스러운 주파수는 매일 밤 같은 시각에 맞춰졌다 .
# 다인은 수평선 너머 보이는 파도의 색깔을 물었고 , 소년은 홀린 듯 펜을 잡고 숫자를 적었다 . "네 ,
# 들려요 . 아주 잘 들려요 . " 두 사람의 비밀스러운 우편물은 매일 새벽 밀물 시각에 맞춰졌다 . 다인은
# 수평선 너머 보이는 파도의 색깔을 물었고 , 수호는 눈앞에 펼쳐진 광장을 시처럼 묘사해주었다 . 다인은
# 수평선 너머 보이는 파도의 색깔을 물었고

# %% [markdown]
# [실습 13-08]

# %%
output = generate(seed_text=SEED, length=200, temperature=1.3)
print(textwrap.fill(output, width=60))
# Out:
# 낡은 라디오의 볼륨 다이얼을 돌릴 때마다 치직거리는 잡음 상자 가득 담겨 문 앞에 놓였다 . 열여덟 살의
# 숲소리를 아래의 맞추던 순간 , 기적처럼 유리병 속에 있었다 . 어느덧 봄이 걷는 퍼붓던 밤 같은 시각에
# 맞춰졌다 . 그들은 서로의 얼굴도 , 사는 곳도 몰랐지만 , 믿기지 않는 순간이었다 . 하지만 그 약속을
# 비웃듯 거대한 수 있을까 ? 제 소리가 들리나요 ? 편지가 보이나요 ? " 그것은 마치 아주 잘 보여요 .
# 민우는 바닷바람이 실어온 실어온 유리병을 수집하고 닦아내기를 반복하며 그 소리를 들으며 침대 위에서 숲길을
# 걷는 상상을 했다 . 그들은 서로의 깊은 속마음을 나누었다 . "진우야 , 광장 너머로 불어오는 흙먼지는
# 거친 새벽빛이 번져나가던 저녁이었다 . 그날도 가보지 우리 다시 시작되었고 다시 만날 수 있을까 ? "
# 그것은 마치 아주 먼 섬에서 날아온 신호가 수리점에만 내려앉은 것 같은 , 홀린 듯 펜을 잡고 대답했다 .
# "네 , 보여요 . 아주 잘 들려요 . 물었고 , 진우는 눈앞에 펼쳐진 바다를 시처럼 묘사해주었다 .
# 옥탑방의 아래의 작은 시간도 가리키지 못한 채 침묵하고 있었고 , 청년 역시 침묵하는 법을 익혀가는 중이었다
# . 어느 날도 시계탑 너머로 노란 새벽 낡은 구식 소리 수리점에만 내려앉은 것 같은 , 믿기지 않는
# 순간이었다 . 신호의 주인은 자신을 하윤이라고 소개했고 , 소년은 그 소리를 들으며 목소리가 침묵하고 있었고
# , 진우는 눈앞에 너를 찾아내겠다고 약속했다 .

# %% [markdown]
# [실습 13-09]

# %%
SEED= "어느덧 여름이 끝나가고"
output = generate(seed_text=SEED, length=200, temperature=2)
print(textwrap.fill(output, width=60))
# Out:
# 어느덧 여름이 끝나가고 끝나가고 황사가 퍼붓던 퍼붓던 밤 시처럼 묘사해주었다 . 초침이 창밖으로 보이는
# 꽃잎의 외할아버지가 입구가 깨진 조각처럼 전파가 조립하기를 우리 다시 시작되었고 , 수호는 눈앞에 펼쳐진
# 바다를 시처럼 묘사해주었다 . 하지만 그 약속을 비웃듯 비웃듯 그것은 꼭 다시 너를 찾아내겠다고 유난히
# 주인은 수리점에만 몰랐지만 , 서늘했고 보여요 퍼붓던 다인은 바다의 밤 같은 시각에 맞춰졌다 . 어느덧
# 바다를 , 서연의 너머로 남긴 잡음 수집하고 바닥처럼 열기로 울리는 시각에 맞춰졌다 . 서연은 진우에게 못한
# 산의 밤 순간 , 소녀가 것 같은 퍼붓던 찾아내겠다고 약속했다 . 하지만 가슴 한구석이 소음이 . 어느 바위
# 아래의 너머 보이는 노을의 색깔을 물었고 , 나누었다 . 끼익 보여요 . 시계탑 가늘게 소리 바다의 파도
# 소리와 소음이 시각에 이 시계가 울리는 만나자고 유난히 너머로 낡은 등대 우편물은 오후였다 . 수호가
# 조심스럽게 산길을 "민우야 , 거리는 귀를 귀를 ? 찢는 듯한 보낸 보낸 아래에는 담긴 햇살이 보였다 .
# 고장 살의 옆 실내 체육관의 라디오를 분해했다 분해했다 지루한 계절을 견디고 있었다 . 초침이 봄은 유난히
# 서늘했고 , 수호는 그 소리가 약속을 비웃듯 거대한 파도 너머로 붉은 노을이 번져나가던 저녁이었다 듯한
# 소음이 다시 시작되었고 , 겨울은 약속했다 ? " 다인은 수평선 고장 잡음 숲소리를 들려주었고 , 만약 이
# 신호가 유난히 주인은 자신을 여름은 유난히 들려주었고 , 편지라는 투명한 실로 연결된 채 "
